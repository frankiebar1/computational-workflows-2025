# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.4.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   ai: Docker AI Agent - Ask Gordon (Docker Inc.)
#     Version:  v1.9.11
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-ai
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.28.0-desktop.1
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-buildx
#   cloud: Docker Cloud (Docker Inc.)
#     Version:  v0.4.29
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-cloud
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.39.4-desktop.1
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.42
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Docker Inc.)
#     Version:  v0.2.0
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-desktop
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.31
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-extension
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.4.0
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-init
#   mcp: Docker MCP Plugin (Docker Inc.)
#     Version:  v0.21.0
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-mcp
#   model: Docker Model Runner (Docker Inc.)
#     Version:  v0.1.41
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-model
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.18.3
#     Path:     /Users/fbarlow/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 27
#   Running: 1
#   Paused: 0
#   Stopped: 26
#  Images: 15
#  Server Version: 28.4.0
#  Storage Driver: overlayfs
#   driver-type: io.containerd.snapshotter.v1
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  CDI spec directories:
#   /etc/cdi
#   /var/run/cdi
#  Discovered Devices:
#   cdi: docker.com/gpu=webgpu
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version: v1.2.5-0-g59923ef
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.10.14-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 8
#  Total Memory: 3.828GiB
#  Name: docker-desktop
#  ID: 1e19f91f-faf8-49fc-babf-a1976acdb9b9
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/fbarlow/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?
# A container is a fully functional and portable computing environment surrounding apps and keeping them independent of other environments running in parallel. [1]
#
# [1] https://en.wikipedia.org/wiki/Containerization_(computing)

# %% [markdown]
# ### Why do we use containers?
# Containers are used because they make it easy to share CPU, memory, storage and network resources at the OS level and offer a logical packing mechanism for applications. [2]
#
# [2] https://cloud.google.com/learn/what-are-containers

# %% [markdown]
# ### What is a docker image?
# Docker images are read only templates that contain instructions for creating a container. [3]
#
# [3] https://aws.amazon.com/compare/the-difference-between-docker-images-and-containers/

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
# !docker container ls -a
# id: 7b5717ed564a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED              STATUS                              PORTS     NAMES
# f219a38c3956   hello-world                                                        "/hello"                 1 second ago         Exited (0) Less than a second ago             fervent_dirac
# f1fdd534a5b0   312ccfaa7abf                                                       "salmon --version"       38 seconds ago       Exited (0) 37 seconds ago                     affectionate_curie
# 79d642d44241   1f751b69ce84                                                       "salmon --version"       About a minute ago   Exited (0) 58 seconds ago                     sweet_merkle
# 7063c254258c   545290230b77                                                       "salmon --version"       3 minutes ago        Exited (133) 3 minutes ago                    lucid_wu
# d6994f9f65ee   b339c3c68396                                                       "salmon --version"       4 minutes ago        Created                                       pensive_jepsen
# e6ee50a4fb56   b339c3c68396                                                       "salmon /bin/sh"         4 minutes ago        Created                                       magical_robinson
# cdf706180ace   35d18d82b719                                                       "/bin/sh"                5 minutes ago        Up 5 minutes                                  sad_galois
# 38f4fe10b238   35d18d82b719                                                       "/bin/sh"                9 minutes ago        Exited (137) 7 minutes ago                    gifted_engelbart
# 9f3a42ac6b1c   35d18d82b719                                                       "bash"                   9 minutes ago        Created                                       nifty_villani
# ffab563574a5   35d18d82b719                                                       "/bin/sh"                9 minutes ago        Exited (137) 7 minutes ago                    thirsty_mahavira
# 7e726256a78d   35d18d82b719                                                       "bash"                   10 minutes ago       Created                                       determined_lederberg
# e47db3479f70   35d18d82b719                                                       "bash"                   10 minutes ago       Created                                       romantic_hawking
# 9f213fa15147   35d18d82b719                                                       "bash"                   10 minutes ago       Created                                       funny_cartwright
# 31a276b99c58   35d18d82b719                                                       "/bin/sh"                11 minutes ago       Exited (137) 7 minutes ago                    vigilant_goldwasser
# a08987dee7e4   ef70f21aeb3c                                                       "/bin/sh"                12 minutes ago       Exited (137) 7 minutes ago                    bold_keller
# cc71a762d22a   ef70f21aeb3c                                                       "bash"                   13 minutes ago       Created                                       admiring_pascal
# 8c47b4bc2458   mycowsay                                                           "cowsay 'wo ist mein…"   37 minutes ago       Exited (0) 37 minutes ago                     relaxed_gauss
# 6fc27225c9d3   9774915fe733                                                       "cowsay 'wo ist mein…"   44 minutes ago       Exited (0) 44 minutes ago                     interesting_payne
# a18c341d32ae   9774915fe733                                                       "cowsay 'hello field…"   45 minutes ago       Exited (0) 45 minutes ago                     stoic_greider
# 31a3d6c6b381   9774915fe733                                                       "cowsay 'hello field…"   45 minutes ago       Exited (0) 45 minutes ago                     magical_brahmagupta
# 3f63b31a9e34   9774915fe733                                                       "cowsay 'Johanna com…"   45 minutes ago       Exited (0) 45 minutes ago                     recursing_curran
# 4fb2850c919e   9774915fe733                                                       "cowsay 'hello nice …"   45 minutes ago       Exited (0) 45 minutes ago                     quirky_murdock
# 097575b06eb9   9774915fe733                                                       "cowsay 'hello bitch…"   46 minutes ago       Exited (0) 46 minutes ago                     wonderful_payne
# 75d21d2ade15   9774915fe733                                                       "cowsay 'hello world'"   46 minutes ago       Exited (0) 46 minutes ago                     objective_chebyshev
# 69cea12520c7   e2f89006997b                                                       "cowsay 'hello world'"   47 minutes ago       Created                                       pedantic_shamir
# 54075c5d7a27   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   About an hour ago    Exited (2) About an hour ago                  quirky_shockley
# 1ad2c3dbd348   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   About an hour ago    Exited (127) About an hour ago                nice_solomon
# 720a0c654156   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   About an hour ago    Exited (0) About an hour ago                  ecstatic_moore

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker container rm magical_mclean # this worked the first time with the container name
# Out:
# Error response from daemon: No such container: magical_mclean

# %%
# !docker container ls -a
# Out:
# CONTAINER ID   IMAGE                                                              COMMAND                  CREATED              STATUS                           PORTS     NAMES
# f219a38c3956   hello-world                                                        "/hello"                 2 seconds ago        Exited (0) 1 second ago                    fervent_dirac
# f1fdd534a5b0   312ccfaa7abf                                                       "salmon --version"       39 seconds ago       Exited (0) 38 seconds ago                  affectionate_curie
# 79d642d44241   1f751b69ce84                                                       "salmon --version"       About a minute ago   Exited (0) 59 seconds ago                  sweet_merkle
# 7063c254258c   545290230b77                                                       "salmon --version"       3 minutes ago        Exited (133) 3 minutes ago                 lucid_wu
# d6994f9f65ee   b339c3c68396                                                       "salmon --version"       4 minutes ago        Created                                    pensive_jepsen
# e6ee50a4fb56   b339c3c68396                                                       "salmon /bin/sh"         4 minutes ago        Created                                    magical_robinson
# cdf706180ace   35d18d82b719                                                       "/bin/sh"                5 minutes ago        Up 5 minutes                               sad_galois
# 38f4fe10b238   35d18d82b719                                                       "/bin/sh"                9 minutes ago        Exited (137) 7 minutes ago                 gifted_engelbart
# 9f3a42ac6b1c   35d18d82b719                                                       "bash"                   9 minutes ago        Created                                    nifty_villani
# ffab563574a5   35d18d82b719                                                       "/bin/sh"                9 minutes ago        Exited (137) 7 minutes ago                 thirsty_mahavira
# 7e726256a78d   35d18d82b719                                                       "bash"                   10 minutes ago       Created                                    determined_lederberg
# e47db3479f70   35d18d82b719                                                       "bash"                   10 minutes ago       Created                                    romantic_hawking
# 9f213fa15147   35d18d82b719                                                       "bash"                   10 minutes ago       Created                                    funny_cartwright
# 31a276b99c58   35d18d82b719                                                       "/bin/sh"                11 minutes ago       Exited (137) 7 minutes ago                 vigilant_goldwasser
# a08987dee7e4   ef70f21aeb3c                                                       "/bin/sh"                12 minutes ago       Exited (137) 7 minutes ago                 bold_keller
# cc71a762d22a   ef70f21aeb3c                                                       "bash"                   13 minutes ago       Created                                    admiring_pascal
# 8c47b4bc2458   mycowsay                                                           "cowsay 'wo ist mein…"   37 minutes ago       Exited (0) 37 minutes ago                  relaxed_gauss
# 6fc27225c9d3   9774915fe733                                                       "cowsay 'wo ist mein…"   44 minutes ago       Exited (0) 44 minutes ago                  interesting_payne
# a18c341d32ae   9774915fe733                                                       "cowsay 'hello field…"   45 minutes ago       Exited (0) 45 minutes ago                  stoic_greider
# 31a3d6c6b381   9774915fe733                                                       "cowsay 'hello field…"   45 minutes ago       Exited (0) 45 minutes ago                  magical_brahmagupta
# 3f63b31a9e34   9774915fe733                                                       "cowsay 'Johanna com…"   45 minutes ago       Exited (0) 45 minutes ago                  recursing_curran
# 4fb2850c919e   9774915fe733                                                       "cowsay 'hello nice …"   45 minutes ago       Exited (0) 45 minutes ago                  quirky_murdock
# 097575b06eb9   9774915fe733                                                       "cowsay 'hello bitch…"   46 minutes ago       Exited (0) 46 minutes ago                  wonderful_payne
# 75d21d2ade15   9774915fe733                                                       "cowsay 'hello world'"   46 minutes ago       Exited (0) 46 minutes ago                  objective_chebyshev
# 69cea12520c7   e2f89006997b                                                       "cowsay 'hello world'"   47 minutes ago       Created                                    pedantic_shamir
# 54075c5d7a27   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   About an hour ago    Exited (2) About an hour ago               quirky_shockley
# 1ad2c3dbd348   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   About an hour ago    Exited (127) About an hour ago             nice_solomon
# 720a0c654156   community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29   "/usr/local/bin/_ent…"   About an hour ago    Exited (0) About an hour ago               ecstatic_moore

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. I clicked on the download section and picked the correct version for my architecture.
# 2. To run it I pressed the file -> open and selected a fastq from an earlier notebook

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker image pull community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# !docker container create community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# Out:
# 0.12.1--af7a5314d5015c29: Pulling from library/fastqc
# Digest: sha256:b7f6caf359264cf86da901b0aa5f66735a6506fcfbf103c66db6987253ad44c1
# Status: Image is up to date for community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# 67500e1a575d6424dc229bff26a193d833ed47c83752e22ec38d56522329e899

# %%
# run the container and save the results to a new "fastqc_results" directory
# !mkdir fastqc_results

# !docker run --rm \
  -v /Users/fbarlow/Desktop/VSCODE-MAIN/CWBD/computational-workflows-2025/notebooks/day_02/fetchngs-out/fastq:/data \
  -v $(pwd)/fastqc_results:/out \
  community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29 \
  fastqc -o /out /data/SRX19144486_SRR23195516_1.fastq.gz
# Out:
# mkdir: cannot create directory ‘fastqc_results’: File exists
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# ^C

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?

# %% [markdown]
# ### What would you say, which approach is more reproducible?
# The container is more reproducible as it's more of an isolated system with it's own dependencies

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# RUN indicates the commands that are to be ran while building the image while ENV sets environment variables inside the image.

# %%
# build the docker image
# !docker build -t mycowsay -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.5s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.8s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.0s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.1s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.2s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.2s
# [+] Building 1.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.3s
# [+] Building 1.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.3s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 1.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 1.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  0.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 2.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 3.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 3.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  1.9s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
# [+] Building 3.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.1s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.3s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.4s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.6s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
# [+] Building 3.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.6s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
# [+] Building 4.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.7s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
# [+] Building 4.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.9s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
# [+] Building 4.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  2.9s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
# [+] Building 4.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.1s
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.3s
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.3s
#  => => # 64 Packages [406 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main arm64 Package
#  => => # s [16.3 kB]
#  => => # Fetched 8523 kB in 2s (3662 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 4.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.5s
#  => => # Reading package lists...
#  => => # Building dependency tree...
#  => => # Reading state information...
#  => => # The following additional packages will be installed:
#  => => #   libbrotli1 libcurl4 libgdbm-compat4 libgdbm6 libldap-2.4-2 libnghttp
#  => => # 2-14
# [+] Building 4.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.6s
#  => => #   libssh2-1 libtext-charwidth-perl perl perl-modules-5.32
#  => => # 0 upgraded, 17 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 5.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.8s
#  => => #   libssh2-1 libtext-charwidth-perl perl perl-modules-5.32
#  => => # 0 upgraded, 17 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 5.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  3.9s
#  => => #   libssh2-1 libtext-charwidth-perl perl perl-modules-5.32
#  => => # 0 upgraded, 17 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 5.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.1s
#  => => #   libssh2-1 libtext-charwidth-perl perl perl-modules-5.32
#  => => # 0 upgraded, 17 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 5.5s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.2s
#  => => #   libssh2-1 libtext-charwidth-perl perl perl-modules-5.32
#  => => # 0 upgraded, 17 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 5.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.4s
#  => => #   libssh2-1 libtext-charwidth-perl perl perl-modules-5.32
#  => => # 0 upgraded, 17 newly installed, 0 to remove and 0 not upgraded.
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
# [+] Building 5.7s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.4s
#  => => # Need to get 8772 kB of archives.
#  => => # After this operation, 50.5 MB of additional disk space will be used.
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
# [+] Building 5.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.5s
#  => => # Get:1 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 perl-modules-5.32 all 5.32.1-4+deb11u4 [2824 kB]
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
# [+] Building 6.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.7s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
#  => => # Get:4 http://deb.debian.org/debian-security bullseye-security/main arm
#  => => # 64 libperl5.32 arm64 5.32.1-4+deb11u4 [3917 kB]
# [+] Building 6.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  4.8s
#  => => # Get:2 http://deb.debian.org/debian bullseye/main arm64 libgdbm6 arm64
#  => => # 1.19-2 [64.0 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye/main arm64 libgdbm-compat4
#  => => #  arm64 1.19-2 [44.6 kB]
# ...
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.0s
#  => => # Setting up libgdbm-compat4:arm64 (1.19-2) ...
#  => => # Setting up libperl5.32:arm64 (5.32.1-4+deb11u4) ...
#  => => # Setting up libcurl4:arm64 (7.74.0-1.3+deb11u15) ...
#  => => # Setting up curl (7.74.0-1.3+deb11u15) ...
#  => => # Setting up perl (5.32.1-4+deb11u4) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
# [+] Building 7.4s (6/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#
#
#
#
#
#
# [+] Building 7.6s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.1s
# [+] Building 7.7s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 7.9s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 8.0s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 8.2s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 8.3s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 8.5s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 8.6s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 8.7s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     1.3s
#  => => exporting layers                                                    1.3s
# [+] Building 8.9s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.3s
#  => => exporting manifest sha256:17f652afc7a15410fc7149ed7132df10c6799041  0.0s
#  => => exporting config sha256:91ab9d174c36c03ff7657287967710161f6d85edbd  0.0s
#  => => exporting attestation manifest sha256:d4c34af3f26effba45046e6f54ec  0.0s
#  => => exporting manifest list sha256:5f8d4eeac047764abc23460e8c4665545e4  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.2s
# [+] Building 9.0s (6/7)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     1.6s
#  => => exporting layers                                                    1.3s
#  => => exporting manifest sha256:17f652afc7a15410fc7149ed7132df10c6799041  0.0s
#  => => exporting config sha256:91ab9d174c36c03ff7657287967710161f6d85edbd  0.0s
#  => => exporting attestation manifest sha256:d4c34af3f26effba45046e6f54ec  0.0s
#  => => exporting manifest list sha256:5f8d4eeac047764abc23460e8c4665545e4  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.3s
# [+] Building 9.1s (7/7) FINISHED                           docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 859B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => [2/2] RUN apt-get update  && apt-get install -y --no-install-recommen  6.2s
#  => exporting to image                                                     1.6s
#  => => exporting layers                                                    1.3s
#  => => exporting manifest sha256:17f652afc7a15410fc7149ed7132df10c6799041  0.0s
#  => => exporting config sha256:91ab9d174c36c03ff7657287967710161f6d85edbd  0.0s
#  => => exporting attestation manifest sha256:d4c34af3f26effba45046e6f54ec  0.0s
#  => => exporting manifest list sha256:5f8d4eeac047764abc23460e8c4665545e4  0.0s
#  => => naming to docker.io/library/mycowsay:latest                         0.0s
#  => => unpacking to docker.io/library/mycowsay:latest                      0.3s
#
#  2 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/tw547coa3lrojx0g7fsk8vp5n\docker-desktop://dashboard/build/desktop-linux/desktop-linux/tw547coa3lrojx0g7fsk8vp5n]8;;\

# %%
# make sure that the image has been built
# !docker images
# Out:
# REPOSITORY                                                 TAG                        IMAGE ID       CREATED          SIZE
# mycowsay                                                   latest                     5f8d4eeac047   21 seconds ago   183MB
# mysalmon                                                   latest                     f2188558e7b7   19 hours ago     440MB
# hello-world                                                latest                     54e66cc1dd1f   7 weeks ago      16.9kB
# community.wave.seqera.io/library/fastqc                    0.12.1--af7a5314d5015c29   b7f6caf35926   11 months ago    1.37GB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0       e0de72408557   17 months ago    1.99GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0          099d0e113ec8   18 months ago    1.82GB
# combinelab/salmon                                          latest                     cefd8bb0b2ed   18 months ago    152MB
# quay.io/nf-core/ubuntu                                     20.04                      59e9d08d8dc1   2 years ago      110MB
# quay.io/biocontainers/pandas                               1.5.2                      cbb54fcf8730   2 years ago      493MB
# quay.io/biocontainers/gsea                                 4.3.2--hdfd78af_0          0010041fff53   2 years ago      849MB
# quay.io/biocontainers/r-base                               4.2.1                      6721ee8bfba2   2 years ago      1.17GB
# quay.io/biocontainers/p7zip                                16.02                      731aaeef376a   3 years ago      47.7MB
# quay.io/biocontainers/python                               3.9--1                     d97d2b329b4e   4 years ago      275MB
# quay.io/biocontainers/gawk                                 5.1.0                      9d300f3d0a35   5 years ago      53.4MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3      c06884d353ef   55 years ago     452MB
# quay.io/biocontainers/wget                                 1.20.1                     7e5ba9e87a25   55 years ago     26.9MB

# %%
# run the docker file 
# !docker run mycowsay cowsay "wo ist mein Hund?"
# Out:
#  ___________________
# < wo ist mein Hund? >
#  -------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image
# !docker buildx build --platform linux/amd64 -t mysalmon -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 546B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 546B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 546B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 546B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.7s (7/7) FINISHED                           docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 546B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => CACHED [2/3] RUN apt-get update && apt-get install -y curl tar && apt  0.0s
#  => CACHED [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releas  0.0s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:9cb5dcf49d716ee49f1f557aa65303557e75c83c  0.0s
#  => => exporting config sha256:a407251e0164426b14c3f49aa5bad35e9030e5bc85  0.0s
#  => => exporting attestation manifest sha256:bd94084759c8b6ad1c3e8474e2b9  0.0s
#  => => exporting manifest list sha256:f2188558e7b7d837fb42e22414eb1e20fd8  0.0s
#  => => naming to docker.io/library/mysalmon:latest                         0.0s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/wd3qpt5r1sk4cqpyvjdksuuh1\docker-desktop://dashboard/build/desktop-linux/desktop-linux/wd3qpt5r1sk4cqpyvjdksuuh1]8;;\

# %%
# run the docker image to give out the version of salmon
# !docker run --platform linux/amd64 mysalmon
# Out:
# salmon 1.5.2

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %% [markdown]
# It's not necessary to create a docker image every time as we can find images on https://hub.docker.com/ if they're uploaded.
#
# BioContainers is a project that aims to create, manage and distribute bioinformatics packages and containers based on the frameworks Conda, Docker and Singularity. [4]
#
# [4] https://biocontainers-edu.readthedocs.io/en/latest/what_is_biocontainers.html

# %%
# !docker pull combinelab/salmon
# Out:
# Using default tag: latest
# latest: Pulling from combinelab/salmon
#
# 9485d7ab: Pulling fs layer
# 893c1bc1: Pulling fs layer
# 0bdd40c3: Pulling fs layer
# 1ed9ab84: Pulling fs layer
# Digest: sha256:cefd8bb0b2ed9b07f22b5f0fc317ddda540e5b0dc00810d1ff0d92fee5d80370Downloading  5.243MB/16.42MB
# Status: Downloaded newer image for combinelab/salmon:latest
# docker.io/combinelab/salmon:latest

# %%
# !docker run --platform linux/amd64 combinelab/salmon salmon
# Out:
# salmon v1.10.3
#
# Usage:  salmon -h|--help or
#         salmon -v|--version or
#         salmon -c|--cite or
#         salmon [--no-version-check] <COMMAND> [-h | options]
#
# Commands:
#      index      : create a salmon index
#      quant      : quantify a sample
#      alevin     : single cell analysis
#      swim       : perform super-secret operation
#      quantmerge : merge multiple quantifications into a single file

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
#
# What is https://seqera.io/containers/ ?

# %% [markdown]
# Docker images can be created by selecting desired packages at https://seqera.io/containers/ and adding them to a container. When we are satisfied with the desired packages we can generate a container and Seqera will build  an image with all the selected packages which we can build on our machine.
